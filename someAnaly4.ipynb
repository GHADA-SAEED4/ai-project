# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# ============================================
# comparison for time
# ============================================

bt = pd.read_csv("backtracking_results_4x4.csv")
ca = pd.read_csv("cultural_results_4x4.csv")

comparison = pd.DataFrame({
    "puzzle_number": bt["puzzle_number"],
    "bt_time": bt["time"],
    "ca_time": ca["time"],
    "bt_valid": bt["valid"],
    "ca_valid": ca["valid"]
})

print(comparison)
# Out:
#     puzzle_number  bt_time  ca_time  bt_valid  ca_valid
# 0               1   0.0002   0.0053      True      True
# 1               2   0.0001   0.0054      True      True
# 2               3   0.0001   0.0045      True      True
# 3               4   0.0001   0.0046      True      True
# 4               5   0.0001   0.0048      True      True
# 5               6   0.0002   0.0064      True      True
# 6               7   0.0001   0.0050      True      True
# 7               8   0.0001  23.2925     False     False
# 8               9   0.0001   0.0053      True      True
# 9              10   0.0001   0.0051      True      True
# 10             11   0.0004   0.0060      True      True
# 11             12   0.0004   0.0062      True      True
# 12             13   0.0005   0.0071      True      True
# 13             14   0.0004   0.0088      True      True
# 14             15   0.0005   0.0067      True      True

# %%
# ============================================
# comparison for iterations
# ============================================

comparison = pd.DataFrame({
    "puzzle_number": bt["puzzle_number"],
    "bt_iterations": bt["iterations"],
    "ca_generations": ca["generations"]
})

print(comparison)
# Out:
#     puzzle_number  bt_iterations  ca_generations
# 0               1             11               1
# 1               2             11               1
# 2               3              9               1
# 3               4              9               1
# 4               5              9               1
# 5               6             13               1
# 6               7             11               1
# 7               8              5             500
# 8               9             11               1
# 9              10             11               1
# 10             11             15               1
# 11             12             15               1
# 12             13             15               1
# 13             14             15               1
# 14             15             17               1

# %%
# ============================================
# Number of solved puzzles using every algo
# ============================================
print("Backtracking solved:", bt["valid"].sum())
print("Cultural solved:", ca["valid"].sum())

total_correct = [bt["valid"].sum(), ca["valid"].sum()]
solvers = ["Backtracking", "Cultural"]

plt.figure(figsize=(6,4))
plt.bar(solvers, total_correct, color=["skyblue","lightgreen"])
plt.ylabel("Number of Correct Solutions")
plt.title("Total Correct Solutions per Solver")
plt.show()
# Out:
# Backtracking solved: 14
# Cultural solved: 14

# %%
# ============================================
# mean time for every algo
# ============================================
print("Average time Backtracking:", bt["time"].mean())
print("Average time Cultural:", ca["time"].mean())
# Out:
# Average time Backtracking: 0.00022666666666666668
# Average time Cultural: 1.5582466666666663

# %%
# ============================================
# mean iterations for every algo
# ============================================
print("Average Backtracking iterations:", bt["iterations"].mean())
print("Average Cultural generations:", ca["generations"].mean())
# Out:
# Average Backtracking iterations: 11.8
# Average Cultural generations: 34.266666666666666

# %%
# ============================================
# time visualization
# ============================================
plt.figure(figsize=(12,6))
x = np.arange(len(bt))  # الألغاز
plt.bar(x - 0.2, bt["time"], width=0.4, label="Backtracking")
plt.bar(x + 0.2, ca["time"], width=0.4, label="Cultural")
plt.xlabel("Puzzle Number")
plt.ylabel("Time (seconds)")
plt.title("Solver Time Comparison per Puzzle")
plt.xticks(x, bt["puzzle_number"])
plt.legend()
plt.show()

# %%
# ============================================
# iterations visualization
# ============================================

x = np.arange(len(bt))
plt.figure(figsize=(12,6))
plt.bar(x - 0.2, bt["iterations"], width=0.4, label="Backtracking iterations")
plt.bar(x + 0.2, ca["generations"], width=0.4, label="Cultural generations")
plt.xlabel("Puzzle Number")
plt.ylabel("Iterations / Generations")
plt.title("Backtracking vs Cultural Algorithm")
plt.xticks(x, bt["puzzle_number"])
plt.legend()
plt.show()
